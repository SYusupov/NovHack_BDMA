# %%
import os
import pandas as pd
import mlflow
import requests
import json

import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet

# %%
X_train = pd.read_csv("gs://novhack_2023_training_data/X_train.csv", index_col=0)["samples"]

# %%
# Methods from https://gaurav5430.medium.com/using-nltk-for-lemmatizing-sentences-c1bfff963258
from sentence_lemmatizer import SentenceLemmatizer

sl = SentenceLemmatizer()
sl.lemmatize(X_train[0])
# Out:
# 'turn ignit switch wait time be requir disconnect cabl batteri termin therefor make read disconnect cabl batteri notic proceed work see page disconnect cabl system need be initi cabl be reconnect see page seat type side remov seat assembl see page seat type side remov seat assembl see page split seat type side remov seat assembl see page split seat type side remov seat assembl see page seat type side remov seat assembl see page seat type side remov seat assembl see page remov floor step cover rear seat remov quarter scuff plate lh rear seat remov quarter scuff plate rh rear seat remov floor side airbag sensor cover detach clip claw remov cover wait second disconnect cabl batteri termin disabl sr system turn ignit switch wait time be requir disconnect cabl batteri termin therefor make read disconnect cabl batteri notic proceed work see page disconnect cabl system need be initi cabl be reconnect see page'

# %%
mini_test = X_train[0:20]

# %%
mini_test = mini_test.apply(sl.lemmatize)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(mini_test)

# %%
feature_names = vectorizer.get_feature_names_out()
dense = X.todense()
denselist = dense.tolist()
df = pd.DataFrame(denselist, columns=feature_names)
df
# Out:
#         a119  a340358inspect  a357588aft  a357589c02  a358042aft      abov  \
# 0   0.000000         0.00000     0.00000     0.00000     0.00000  0.000000
# 1   0.000000         0.00000     0.00000     0.00000     0.00000  0.000000
# 2   0.000000         0.00000     0.00000     0.00000     0.00000  0.000000
# 3   0.000000         0.00000     0.00000     0.00000     0.00000  0.024633
# 4   0.000000         0.00000     0.00000     0.00000     0.00000  0.000000
# 5   0.025545         0.00000     0.00000     0.00000     0.00000  0.000000
# 6   0.000000         0.00000     0.00000     0.00000     0.00000  0.000000
# 7   0.000000         0.00000     0.00000     0.00000     0.00000  0.000000
# 8   0.000000         0.00000     0.00000     0.00000     0.00000  0.000000
# 9   0.000000         0.00000     0.00000     0.00000     0.00000  0.000000
# 10  0.000000         0.00000     0.00000     0.00000     0.00000  0.000000
# ...

# %%
# %timeit

from vectorizer import TextPreprocesser

tp = TextPreprocesser()
X_vectorized = tp.vectorize(X_train)
